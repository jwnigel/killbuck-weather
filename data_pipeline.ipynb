# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data/KillbuckWeatherData.csv')

# %%
data.head()
# Out:
#           dt                         dt_iso  timezone         city_name  \
# 0  283996800  1979-01-01 00:00:00 +0000 UTC    -18000  Township Road 22
# 1  284000400  1979-01-01 01:00:00 +0000 UTC    -18000  Township Road 22
# 2  284004000  1979-01-01 02:00:00 +0000 UTC    -18000  Township Road 22
# 3  284007600  1979-01-01 03:00:00 +0000 UTC    -18000  Township Road 22
# 4  284011200  1979-01-01 04:00:00 +0000 UTC    -18000  Township Road 22
#
#          lat        lon   temp  feels_like  temp_min  temp_max  ...  wind_deg  \
# 0  40.441789 -82.040213  51.49       50.86     50.95     53.38  ...       176
# 1  40.441789 -82.040213  51.55       50.92     50.94     53.38  ...       178
# 2  40.441789 -82.040213  51.67       51.06     50.95     53.38  ...       185
# 3  40.441789 -82.040213  54.54       53.96     53.87     55.26  ...       186
# 4  40.441789 -82.040213  54.57       53.96     53.85     55.29  ...       187
#
# ...
